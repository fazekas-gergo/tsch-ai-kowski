# %%
import mido
from mido import MidiFile

# %%
file = MidiFile('data/raw/albeniz/alb_esp1.mid')
file
# Out:
# MidiFile(type=1, ticks_per_beat=480, tracks=[
#   MidiTrack([
#     MetaMessage('track_name', name='Espana Op. 165', time=0),
#     MetaMessage('track_name', name='Prelude', time=0),
#     MetaMessage('copyright', text='Copyright © 2001 by Bernd Krueger', time=0),
#     MetaMessage('text', text='Isaac Albeniz', time=0),
#     MetaMessage('text', text='Andantino', time=0),
#     MetaMessage('text', text='Fertiggestellt  27.01.2001\n', time=0),
#     MetaMessage('text', text='Update: 18.03.2001\n', time=0),
#     MetaMessage('text', text='Normierung: 23.12.2002\n', time=0),
#     MetaMessage('text', text='Update am 28.10.2010\n', time=0),
#     MetaMessage('text', text='Dauer: 1:36 Minuten\n', time=0),
#     MetaMessage('smpte_offset', frame_rate=25, hours=32, minutes=0, seconds=3, frames=0, sub_frames=0, time=0),
#     MetaMessage('time_signature', numerator=3, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
# ...

# %%
piano_tracks = [track for track in file.tracks if track.name.lower() in ['piano left', 'piano right']]
[track.name for track in piano_tracks]
# Out:
# ['Piano right', 'Piano left']

# %%
def convert_absolute_time(messages):
    time = 0
    for msg in messages:
        time += msg['time']
        msg['time'] = time    

def _merge_pair(note_on, note_off):
    return {'note': note_on['note'], 'velocity': note_on['velocity'], 
            'start': note_on['time'], 'length': note_off['time'] - note_on['time']}
        
def _find_pairs(note_ons, note_offs):
    for note_on in note_ons:
        note_off_index = next(i for i, note_off in enumerate(note_offs) if note_off['note'] == note_on['note'])
        note_off = note_offs.pop(note_off_index)
        yield note_on, note_off
        
def merge_message_pairs(messages):
    note_ons = [msg for msg in messages if msg['type'] == 'note_on' and msg['velocity'] != 0]
    note_offs = [msg for msg in messages if msg['type'] == 'note_off' or msg['velocity'] == 0]
    return [_merge_pair(note_on, note_off) for note_on, note_off in _find_pairs(note_ons, note_offs)]

for track in piano_tracks:
    messages = [msg.dict() for msg in track if msg.type in ['note_on', 'note_off']]
    convert_absolute_time(messages)
    messages = merge_message_pairs(messages)
    for msg in messages:
        print(msg)
# Out:
# {'note': 81, 'velocity': 60, 'start': 240, 'length': 240}
# {'note': 88, 'velocity': 66, 'start': 480, 'length': 1560}
# {'note': 86, 'velocity': 55, 'start': 2040, 'length': 60}
# {'note': 88, 'velocity': 47, 'start': 2100, 'length': 60}
# {'note': 86, 'velocity': 62, 'start': 2160, 'length': 240}
# {'note': 84, 'velocity': 57, 'start': 2400, 'length': 240}
# {'note': 86, 'velocity': 57, 'start': 2640, 'length': 240}
# {'note': 88, 'velocity': 62, 'start': 2880, 'length': 240}
# {'note': 89, 'velocity': 64, 'start': 3120, 'length': 240}
# {'note': 91, 'velocity': 67, 'start': 3360, 'length': 240}
# {'note': 88, 'velocity': 66, 'start': 3600, 'length': 240}
# {'note': 89, 'velocity': 64, 'start': 3840, 'length': 240}
# {'note': 88, 'velocity': 61, 'start': 4080, 'length': 120}
# {'note': 86, 'velocity': 59, 'start': 4200, 'length': 60}
# {'note': 88, 'velocity': 55, 'start': 4260, 'length': 60}
# {'note': 86, 'velocity': 67, 'start': 4320, 'length': 480}
# ...

# %%
mem1=0
for i in mididict:
    time = i['time'] + mem1
    i['time'] = time
    mem1 = i['time']
# make every note_on with 0 velocity note_off
    if i['type'] == 'note_on' and i['velocity'] == 0:
        i['type'] = 'note_off'
# put note, starttime, stoptime, as nested list in a list. # format is [type, note, time, channel]
    mem2=[]
    if i['type'] == 'note_on' or i['type'] == 'note_off':
        mem2.append(i['type'])
        mem2.append(i['note'])
        mem2.append(i['time'])
        mem2.append(i['channel'])
        output.append(mem2)
# put timesignatures
    if i['type'] == 'time_signature':
        mem2.append(i['type'])
        mem2.append(i['numerator'])
        mem2.append(i['denominator'])
        mem2.append(i['time'])
        output.append(mem2)
# viewing the midimessages.
for i in output:
    print(i)
print(mid.ticks_per_beat)
